# %%
import os
import pandas as pd

# %%
indir = '../../data/ADHD200/RawData'

# %%
csvs = [i for i in os.listdir(indir) if i.endswith('.csv')]
csvs.sort()

# %%
df1 = pd.read_csv(os.path.join(indir,csvs[0]))
df2 = pd.read_csv(os.path.join(indir,csvs[1]))

# %%
dfs = [pd.read_csv(os.path.join(indir,csv)) for csv in csvs]

# %%
len(df1)
# Out:
# 26

# %%
len(df2)
# Out:
# 83

# %%
len(df_all)
# Out:
# 717

# %%
df1
# Out:
#     ScanDir ID  Site  Gender    Age  Handedness       DX Secondary Dx   \
# 0        26001     2       1  16.92           1  pending       pending
# 1        26002     2       1  15.68           1  pending       pending
# 2        26004     2       0  14.99           1  pending       pending
# 3        26005     2       0  15.16           1  pending       pending
# 4        26009     2       1  16.91           0  pending       pending
# 5        26014     2       0  16.21           1  pending       pending
# 6        26015     2       0  15.20           1  pending       pending
# 7        26016     2       1  16.07           1  pending       pending
# 8        26017     2       0  14.56           1  pending       pending
# 9        26022     2       1  17.83           1  pending       pending
# 10       26024     2       0  17.77           1  pending       pending
# 11       26027     2       0  11.28           1  pending       pending
# ...

# %%
df2
# Out:
#     ScanDir ID  Site  Gender    Age  Handedness  DX  Secondary Dx   \
# 0      2371032     3       0  10.73           1   0            NaN
# 1      2026113     3       0  12.99           1   1            NaN
# 2      3434578     3       0   8.12           1   0            NaN
# 3      8628223     3       0  10.81           1   0  Simple phobia
# 4      1623716     3       0  12.65           1   1            NaN
# ..         ...   ...     ...    ...         ...  ..            ...
# 78     2360428     3       1   8.56           1   0            NaN
# 79     2903997     3       0  11.91           1   0            NaN
# 80     2703289     3       1  11.10           1   0            NaN
# 81     1577042     3       1   9.06           1   1            NaN
# 82     2621228     3       0   8.98           1   0            NaN
#
#     ADHD Measure  ADHD Index  Inattentive  ...  Performance IQ  Full2 IQ  \
# 0              2          47           55  ...             119       NaN
# ...

# %%
df2.head()
# Out:
#    ScanDir ID  Site  Gender    Age  Handedness  DX  Secondary Dx   \
# 0     2371032     3       0  10.73           1   0            NaN
# 1     2026113     3       0  12.99           1   1            NaN
# 2     3434578     3       0   8.12           1   0            NaN
# 3     8628223     3       0  10.81           1   0  Simple phobia
# 4     1623716     3       0  12.65           1   1            NaN
#
#    ADHD Measure  ADHD Index  Inattentive  ...  Performance IQ  Full2 IQ  \
# 0             2          47           55  ...             119       NaN
# 1             2          90           89  ...             108       NaN
# 2             2          42           42  ...              98       NaN
# 3             2          42           49  ...              86       NaN
# 4             2          87           90  ...              88       NaN
#
#    Full4 IQ  Med Status  QC_Rest_1  QC_Rest_2  QC_Rest_3  QC_Rest_4  \
# ...

# %%
df_all = pd.concat(dfs, axis=0, ignore_index=True)

# %%
df_all.to_csv('../Data/df_all.csv')
