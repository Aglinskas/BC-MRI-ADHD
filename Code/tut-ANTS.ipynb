# %%
import ants

# %%
pwd
# Out:
# '/mmfs1/data/aglinska/BC-MRI-ADHD/Code'

# %%
im = ants.image_read('../Assets/Atlas_brain_2mm.nii')

# %%
im
# Out:
# ANTsImage (RPI)
# 	 Pixel Type : float (float32)
# 	 Components : 1
# 	 Dimensions : (91, 109, 91)
# 	 Spacing    : (2.0, 2.0, 2.0)
# 	 Origin     : (-90.0, 126.0, -72.0)
# 	 Direction  : [ 1.  0.  0.  0. -1.  0.  0.  0.  1.]

# %%
im.numpy().shape
# Out:
# (91, 109, 91)

# %%
im.plot_ortho(flat=True)

# %%
im.plot()
