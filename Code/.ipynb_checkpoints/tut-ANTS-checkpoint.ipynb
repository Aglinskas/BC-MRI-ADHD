# %%
import ants

# %%
pwd
# Out:
# '/Users/aidasaglinskas/Desktop/BC-MISC-Tutorials/Python Basics'

# %%
im = ants.image_read('./Data/Atlas_brain_2mm.nii')

# %%
im
# Out:
# ANTsImage (RPI)
# 	 Pixel Type : float (float32)
# 	 Components : 1
# 	 Dimensions : (91, 109, 91)
# 	 Spacing    : (2.0, 2.0, 2.0)
# 	 Origin     : (-90.0, 126.0, -72.0)
# 	 Direction  : [ 1.  0.  0.  0. -1.  0.  0.  0.  1.]

# %%
im.plot()
